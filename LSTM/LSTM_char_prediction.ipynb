# %%
from tensorflow.keras.utils import get_file
import numpy as np

path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600893

# %%
maxlen = 60                                                            
step = 3                                                               

sentences = []                                                         

next_chars = []                                                        

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))                                        
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)       

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)      
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)              
for i, sentence in enumerate(sentences):                               
    for t, char in enumerate(sentence):                                
        x[i, t, char_indices[char]] = 1                                
    y[i, char_indices[next_chars[i]]] = 1    

print('Done.')
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
# Done.

# %%
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.models import Sequential

model = Sequential([
  LSTM(128, input_shape=(maxlen, len(chars))),
  Dense(len(chars), activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               95232
# _________________________________________________________________
# dense_1 (Dense)              (None, 57)                7353
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='RMSProp'
    )

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):                                          
  print('epoch', epoch)
  model.fit(x, y, batch_size=128, epochs=1)                       
  start_index = random.randint(0, len(text) - maxlen - 1)         
  generated_text = text[start_index: start_index + maxlen]        
  print('--- Generating with seed: "' + generated_text + '"')     
  for temperature in [0.2, 0.5, 1.0, 1.2]:                        
    print('------ temperature:', temperature)
    sys.stdout.write(generated_text)

    for i in range(400):                                        
      sampled = np.zeros((1, maxlen, len(chars)))             
      for t, char in enumerate(generated_text):               
        sampled[0, t, char_indices[char]] = 1.              

      preds = model.predict(sampled, verbose=0)[0]            
      next_index = sample(preds, temperature)                 
      next_char = chars[next_index]                           

      generated_text += next_char
      generated_text = generated_text[1:]

      sys.stdout.write(next_char)
# Out:
# epoch 1
# 1565/1565 [==============================] - 314s 200ms/step - loss: 2.4933
# --- Generating with seed: " these tasks; a transvaluation of values, under the new
# pres"
# ------ temperature: 0.2
#  these tasks; a transvaluation of values, under the new
# preselite the and and the hing and the the the sente the the aras in the sone the and the and in the and in the and the sere the the sond the serest and and the sond the seres and in the the and and the seres of the sof and and in the the his and the the the ard of the selle the the sond the the as the the sond the the the the the the the hall the the the here the the the the songe the the soull the s------ temperature: 0.5
# l the the the here the the the the songe the the soull the sericice tise the mon the and and the dere and and the sinde the abecsint deaone thelitte the berest end inone onthingen the ares, and seutily the the grtien the to ather the soul, and aled to the it of the reas of the has and alise to the therast and the greas of the soratits withe sends ind the sone the sion of poraulity the theed boung of them nos are the thes and the hor salle to the destour en------ temperature: 1.0
# of them nos are the thes and the hor salle to the destour en at iony hidodalbts, the fory to helst vensids furilis, hon" sowltijgic, laduttinks porats lalw and ve't saod to hophilloy thar dalcs ir this to lici"tivecious apeorgtbesprstoos ffole th cald(gor, gread ay
# se7cisi
# m,
# tuond nueve blrsoin, theigsso-y
# thim cichigs is and amond forese daretids, tho candurs
# ain dperctie it tho tao,
# wily out fun whe
# verve-coremly"? a boust ait coules
# t)eam rhaknst tival------ temperature: 1.2
# n whe
# verve-coremly"? a boust ait coules
# t)eam rhaknst tivalisy wyotatandet of h anomsenooe?--wit chas aturinesaly
# wo btgeeasy, agw idu-stym anf in betunvand cus alg alder
# gay
# oryalt ofrhicg inte catisve dstinslcteos. is tuutticlopes
# itstsex
# sel ivitibk, foxels, y, exesebonf the the=bee, e-asicmon, ar iwertur--thand malnt,
# rmcang, jiued,ly ofos noocosa nf undsime aufutudo
# ;
# y=. myulutlosdasrky
# wirleicil) ls axsund anther andungutisdaniw olly :oo dore--aumaepoch 2
# 1565/1565 [==============================] - 316s 202ms/step - loss: 2.1228
# --- Generating with seed: "horseback exercise most when the horse is skittish. thus wil"
# ------ temperature: 0.2
# horseback exercise most when the horse is skittish. thus will the self the deall the for the sore the preals of the sente the some the sould the sople to the sente the wall the sould the greation of the sould the stould and which a dered and the some the some the sond and in the sould the sere the sould to the dighe to the sould the some the some the soll the greal dest of the sople for the sond the proust of the some the some the gore of the some the beti------ temperature: 0.5
# he proust of the some the some the gore of the some the beting and who hery at of the mant of the gartion and and belle contion of the sount of the mantime to mather dese to be verues and and who conct what on the wich of the forly and contient in the somenty and and
# the forl with the stirs of his wowh the mente
# the some the sore und interys a desting the gord chinged the proust of sen and eusted in the sont the beling of the some the fored be there dement------ temperature: 1.0
# in the sont the beling of the some the fored be there dement meateduts
# in for that reinged but and angaliyy csils . hine revevers whac mercionvdy
# miconge!, buch, the o loly on hithe
# semf the usmang ald ancture sanles
# and dot
# lowe tho aterice tat the gasiof
# y olluryusse it thas that thin mrevraved in aite., the weaduf to we to
# dety; and ,. the
# "really hat bf
# pundignece it histwruting beaparing celfore seffere for ong chese or to slancs and in ane of rercoth------ temperature: 1.2
# ore seffere for ong chese or to slancs and in ane of rercoth reesint opy e penisey rige
# ay,
# "uoned tomion hedigave inenged, ther mack and,y" al? th: idlle tho peifal longedss andeg-mand iorefule, te toncali gefuigzyanatys pethtiod; nead thungengend one bow that othind in
# thes bfolly ineld gyos
# axwense beerfep, eus indtind hevenace in camuns arfousel, a
# m.--kemly stalse. beveriag
# aud and and, bealaedy onst" ofecentag.; and verisite onandtandidy int leve ed"epoch 3
# 1565/1565 [==============================] - 306s 195ms/step - loss: 1.9597
# --- Generating with seed: "ns made through the
# senses day by day: and the dream-fancy d"
# ------ temperature: 0.2
# ns made through the
# senses day by day: and the dream-fancy dean in the derines and which a sence of the man some of the for the prection of the fore of the present of the great of the fored the preating the canse the farter and reals and the precise the sempasion of the great of the conself the for the fored and and and and and the semperst of the fored and conticions of the some the and and and in the farter and the fored there and the sact in the deal of------ temperature: 0.5
# n the farter and the fored there and the sact in the deal of experion of the sproter which perising of the har, the pease of the singess and one of the where and an a sould there and in the porse for the rement there the gill and inds in the ctreation of the ferter action of the forte of one the fores in a still peach of the gant the seppecion als in the abiture and man the been and the fereven and dise is the grout and is the incerse of the preate of the ------ temperature: 1.0
# d dise is the grout and is the incerse of the preate of the netuence diged
# nowth ourderas gase of ispectabion oninggedsesing 0randly.
#
# f2=y men-chaser surmoster ad the sai h whesm th nougl posten his theynation the fwates orightauled from mhat hemptect of thew the objunhtous here that toate
# cercerses., as nedpselves. and doumition
# in he
# mores of at
# excied tate on the dour therad cerpratifichs fact
# in eniste susk of atther tuid of hisfsiar anda thursbions o------ temperature: 1.2
#
# in eniste susk of atther tuid of hisfsiar anda thursbions orenky wittore hanngymof dagility to hosicant
# colading
# follenfer mive il, whackin acusest of of
# thest, and blemade potionuspy mpaper
# aufilitionavby of litnery phodes couce to day, gredivid alap of the deep a wet ancirt foishind el-oug, (ithersueg cormelied zom bi
# mon be nucons were. heagher coltality sicf roblezaculy walt of the monatt, ledgens, gefoories thail ispertione.
# prenen priceswors? of d-uepoch 4
# 1565/1565 [==============================] - 310s 198ms/step - loss: 1.8460
# --- Generating with seed: "be that it knew
# nothing more of good and evil; only that her"
# ------ temperature: 0.2
# be that it knew
# nothing more of good and evil; only that here a something the seres and man the serment and the selfers of the greation of the streation of the still the great of the self and and the rearing to the seritions and some has and the stinct of the stime to the concertion of the selficions to a man and and the serment the desting to the great the precise the seres and the streation of the complession of the greation of the selfice of the stince ------ temperature: 0.5
# he complession of the greation of the selfice of the stince in the comstition, of the cans and and the stires and serution of the rears and the man and still the camsich and consented for in the foress and the
# more and section of the present and strong, and the know and something in the gore of the former of the greated to the chires in the surperiness, he possible in a dusticicn the end and gion as of the been to the douth the dese impersions and the pari------ temperature: 1.0
# as of the been to the douth the dese impersions and the pariousnes.
#
# go mestional
# serering
# tome word far intayss
# and natnonce atconssadive unfartionsdal syome dam that revire of nather.--we verulo isle astientlye? in the werle arestlf and the extion lan, when lurkely stife ana avimally, comstined ints will which the gromped, and ractire withray onf of plesbutiom and of whace bith the  te him. the fralude heses. it his tred efon corman it is quate cfausce, ------ temperature: 1.2
# fralude heses. it his tred efon corman it is quate cfausce, of a hlich us mecubofed
# ; vely poswition have rigst ace mont the his of itition, the rebgiom, to the dmens, natablese--thsoupatsy, the
# artued prifces. "
# mi live pechoposhore w.
# ce suinds dogrowolictror" the aypedited ne moar morkin , the leitial
#
# upcpliahac
# s, his curale nyoned we ne desire and reriling selualy cceamed
# nation: qoideverceis, (the sovelcenassqey tive but
# the may amon whishom
# s, theyepoch 5
# 1565/1565 [==============================] - 309s 198ms/step - loss: 1.7614
# --- Generating with seed: "tinct of an organic
# being. a living thing seeks above all to"
# ------ temperature: 0.2
# tinct of an organic
# being. a living thing seeks above all to the sempten the an a soul and the still the streng the present the streng to the comple and can in the strent the man a the falle of the self--in the conterd the strenged and the still the strengent and the sense of the strenger of the can of the strenged the can of the some the strenge of the science of the sould the present of the sund and strong himself and such a deast the strenges of the str------ temperature: 0.5
#  and strong himself and such a deast the strenges of the streated of the calless and partion of the
# philosophers of man its all that it is generes and engrated a morality of grature and which can decard on the can it lengen firmang to the self, ond in the ond can of the one has has self--the priots and and san a stren to has a the great to the manter of the soul and state him wart all a being which a reals lore of dither he daster and share of his and even------ temperature: 1.0
# h a reals lore of dither he daster and share of his and even all and now in. the cast. and oe the woll moul and abtion
#
# n2vene mesphess,
#
#
# h1
# =nouver good unowh to the formest and this by
# when contains
# crmolt repoure has onrgicd the hare extence, we have to can: and
# his he-nitifate. but wholowled in
# every in the becipation of deestlogs--plosen our
# us the madien and which, wh has be ut knowild ell--whacer is ark wall,
# it at a wontivel it in.e peals.
# knoot t------ temperature: 1.2
# -whacer is ark wall,
# it at a wontivel it in.e peals.
# knoot ty
# e rethors, what he thered!en an
# spment mpue raval
# _epalestical overmocle hither
# moral
# gne's pemsert frem it is to for mists, treepets
# citreat, and
# bad a viveative exughly
# dy gair to
# wo"s
# morn watto--ys is been a sobeew stil, on man frorory preecitity, of merinesly anrsc.usted to fersicatiod--sueght not relernaress firmadiexing will for be
# daf not hou det as ht mai poderxor -- i scholdment,
#  theepoch 6
# 1565/1565 [==============================] - 310s 198ms/step - loss: 1.6948
# --- Generating with seed: "s"; and in the end,
# in view of all that women write about "w"
# ------ temperature: 0.2
# s"; and in the end,
# in view of all that women write about "whein the man the present the more the man and such a desing and such a philosophers and self--indelies and some his is the more of the command the present in the strenge of the conscience is a something in the world in the more of the self--inder the precession of the streating the man as the more the man the more of the command the man as and the man as the man as the strect streads of the will p------ temperature: 0.5
# s and the man as the man as the strect streads of the will predent in the present ming the expersent and manking religions
# do the distred of the present at the prepers himself for the lake of staces the cruect of the condess--nom in the diffect of the himself as the came there, and some his of the conducts of the
# offers and strong, not of the realon the deeple suple that itself in the present the present whence is condaction of some instirntary as the real------ temperature: 1.0
# present whence is condaction of some instirntary as the reals as they world as it
# i protsentliy
# sleats all the praievend of thirgawilgly bedand
# soitions a distuns, and trating has cistiblieg the valual noths.
#
#
#
# haurder of very and there are as the exclsest discomared,
# bewines, seithorims and of amy. the this they it remsition ant dittictiomeul, uvon the prediming soul.
# as,
# when
# unding inficer beduping groutany." in this its old, and is
# becommenzence is to------ temperature: 1.2
# uping groutany." in this its old, and is
# becommenzence is to cricuses" five, but is gainly lootuto:
#
# whay serly lonuge, as deny-selfiefilifims, decialss he wescience ye3 evenyseso-hew commeltedd, a dicf itme fooeshance lither ac omanhel-cillimuti usivalmy procoushing to he in
# ece of mad. that goomisulukarnc sond"matist, sowe point thay thing, the sprow-dismy mexiercis lesssy,"eand
# vay intamentehrand?,
# whan
# is beting on
# instace:
# gonder all the, that fliedceepoch 7
# 1565/1565 [==============================] - 313s 200ms/step - loss: 1.6415
# --- Generating with seed: "
# burdensome it is preserved because of its supposed vital ut"
# ------ temperature: 0.2
#
# burdensome it is preserved because of its supposed vital uting the fan in the experience of the explising of the soul of a sone that the consequently and the great man the compless the condicions and the are of the soul of the contradical and the are of the some the strection of the soul who has a the former the more of the consequently of the contrary to the sense of the sould to the contradice of the some has a man the fore of the realon of the contrani------ temperature: 0.5
# of the some has a man the fore of the realon of the contranity of the religion of his own to the something in inations
# and realon of the compless the man that the decient and not a man there as its sore of the soul of the great suppeination that is also such and such and that the consequenter and all the every of their to who doing the reaken the man is a probling it is not enowed the consequento in the gare of the discestion and in the same and the most a------ temperature: 1.0
# in the gare of the discestion and in the same and the most ane, than horestary are dowiced injerting
# untally wh replieated arn beon and presentanily of self--bucomerouns," in one agheritic ustal poies morif, waidely those cood by been mone theforaty feishing? loog, of suidlan examstitic havion of the hajurs, for their commisuch
# a
# distingimate worknow. knowledge bieser, advate, letable, thequit
# or dismost of
# encuped, mookine of terity is had hometoises, he ------ temperature: 1.2
# dismost of
# encuped, mookine of terity is had hometoises, he lowgrous ef tugrie thingnong, tratical mecoessions , that know;,"--and lack. howysturrutiona inare of indellinicinquenth; to inly coustian seragno, which ha2ake. equable
# forophouty hagate perhouly macr for dolionso. ada long by _
# accless in that the cank
# onroty as tho gima"ness
# re2rous dyem, withw_taniputacess, and "condlifure concertion. thy
# deallo hamen of sacicient, dinkens
# ", every of that is epoch 8
# 1565/1565 [==============================] - 315s 201ms/step - loss: 1.5972
# --- Generating with seed: "ir teeth into a
# religious interpretation of existence: the f"
# ------ temperature: 0.2
# ir teeth into a
# religious interpretation of existence: the fart of the some the sense of the some such a man is all the state of the such a man as the more some the strength states and something of the sense of the sense of the same the more of the some the present the more propection of the some the strength of the sense of the strong the present the some such a man is all the self-conselvent the contradicts of the some the streation of the same of the se------ temperature: 0.5
#  contradicts of the some the streation of the same of the sensiment, and self-men in the contradict, and replesed in the feeling of the more of all present may be one of the some the persons, the more spirits as in the power of the word of the world of the order of compreessations of the profound of the fart the came of the something it is not a misting to the some life the endimace which is the soul of morality, in some higher of the beginess of the compu------ temperature: 1.0
# oul of morality, in some higher of the beginess of the compuren ratter of huble even self.""
# dis enf.vor? a fort than
# natuates that the chaticis the impersifuedy him,"ser, and
# can staring, irsest the main of any
# woath propen
# end iffetence of juatingars.
#
#
#
#
# go be allitions again at, whomet moral ty the gentrioused but by the flait--without, the eastice, the doom to indeclone, by cimns
# contiming for manithisis litical agate, any more
# doting stikes for dodeg------ temperature: 1.2
# r manithisis litical agate, any more
# doting stikes for dodegfince, were may, but phelogh,rcur;" and weans,
# ejuptce--has he way, a joct vio; by the value
# by arn humplaned of duling
# the nos onistle, epti7s and agaped is
# innature i man--sup, freesy hiffins., foicertives (loo, wholig andrhert non atto fow enl meek not
# metive is partuce, aty knavilwles: is intenctoavienpolye. harear bhoin-thersund comm
# ther-peabeg and us a quearming, that it blo men befing
# readepoch 9
# 1565/1565 [==============================] - 309s 197ms/step - loss: 1.5599
# --- Generating with seed: "ver still sooner with
# the intelligence and taste for beethov"
# ------ temperature: 0.2
# ver still sooner with
# the intelligence and taste for beethover to the most and something to the selfors of the strong and something in the spirit of the strengt to the strong the conscience of the same of the science and self-man is all the present in the selfors of the self-mand and believe the present in the spirit and the means of the present in the fart of the man is allos the strong to the selfers of the selfess the man is all the spirit and such a de------ temperature: 0.5
# lfers of the selfess the man is all the spirit and such a desigion
# theret is always been as the general greater callegnorge the cause the fart of the specient of the actions of the dismorality of the formanistes of all astente of a goder of the exist and in the present the fart of the strengs and possible and the value and instincts, the sense of the superion, the indear that the same of the disting and his
# one of all himself as in the art will the christi------ temperature: 1.0
# ng and his
# one of all himself as in the art will the christian spon
# the prejoument of mindainide of the perlising diffiner (chasces where let meen world recopuless all very everynocy.
#
#
# oh
#  preseavice, him obtconsocius ts evencery. but has which is itngeemoounly and laccrfuci, it is vigure, as
# without culler unceritival bees injegs a destlalage logedually
# can
# an hilled the wain of the what concerned
# man syself, it alwey remances have formed meaqur
# and may,------ temperature: 1.2
# ed
# man syself, it alwey remances have formed meaqur
# and may, to happonedingm
#
# is life the its or sam!" with scrffurrist colseeving in blusion
# for"th sune sundable cale it iver wspcapate lovely being sopeans to mansiculeg. chandwern of mucamsous comar morisness). rulonk of aw7isctoluth
# or unuabyish uper peacablutional, the camn
# there adeursulowted,:
# but only were
# whi allo le, ah. acrseons bact. curerally grefup of the
# poed-noust he was opwess and loik--theyepoch 10
# 1385/1565 [=========================>....] - ETA: 35s - loss: 1.5262
